# %% [markdown]
# ## Noisy Intermediate Scale Quantum

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
from qiskit_ibm_runtime import QiskitRuntimeService , Estimator
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

# %%
# service = QiskitRuntimeService (instance = 'ibm-q/open/main')
service = QiskitRuntimeService(channel="ibm_cloud", channel_strategy="q-ctrl")

backend = service.least_busy(simulator=False, operational=True)
 
# backends = service.backends(simulators=False, min_num_qubits = 5)
backend
# Out:
# <IBMBackend('ibm_osaka')>

# %% [markdown]
# ### Creating Circuits

# %%
from qiskit import QuantumCircuit
n_qubit = 10
circuit = QuantumCircuit(n_qubit)
for i in (range(1,n_qubit+1)):
    circuit.x(np.arange(i, dtype=int))

circuit.measure_all()
display(circuit.draw('mpl'))

# %% [markdown]
# ### Running Circuit in Qiskit Runtime

# %%
from qiskit.circuit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import Session, SamplerV2 as Sampler
 
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
 
# Bell Circuit
qr = QuantumRegister(2, name="qr")
cr = ClassicalRegister(2, name="cr")
qc = QuantumCircuit(qr, cr, name="bell")
qc.h(qr[0])
qc.cx(qr[0], qr[1])
qc.measure(qr, cr)
 
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(qc)
 
with Session(backend=backend) as session:
    sampler = Sampler(session=session)
    job = sampler.run([isa_circuit])
    pub_result = job.result()[0]
    print(f"Sampler job ID: {job.job_id()}")
    print(f"Counts: {pub_result.data.cr.get_counts()}")
# Out:
# C:\Users\Admin\Anaconda3\envs\qc\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:879: UserWarning: Your current pending jobs are estimated to consume 649.5556236231932 quantum seconds, but you only have 600 quantum seconds left in your monthly quota; therefore, it is likely this job will be canceled
#   warnings.warn(warning_message)

# %%
from qiskit.circuit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import Session, SamplerV2 as Sampler
def RunCircuit(object):
    self.circuit = circuit
    self.parse_manager = generate_preset_pass_manager(
            backend=self.backend, optimization_level=1)
        
    def get_job

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(
    channel='ibm_quantum',
    instance='ibm-q/open/main',
)
job = service.job('cred1ed78n6g008e1wc0')
job_result = job.result()

# %%
job_result
# Out:
# PrimitiveResult([PubResult(data=DataBin<>(cr=BitArray(<shape=(), num_shots=4096, num_bits=2>)), metadata={'circuit_metadata': {}})], metadata={'version': 2})

# %%
results.get_counts()
# Out:
# Traceback (most recent call last):
#
#   Cell In[13], line 1
#     results.get_counts()
#
# AttributeError: 'PrimitiveResult' object has no attribute 'get_counts'

# %%
ψ = 50

# %%
π = 40
